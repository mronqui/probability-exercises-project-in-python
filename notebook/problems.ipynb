# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import numpy as np
import random
np.random.seed(2304)

def tirardados(simulaciones = 1000):
    count = 0

    for i in range(simulaciones):
        
        dado1 = random.randint(1,6)
        dado2 = random.randint(1,6)
        resultado = dado1 + dado2
        
        if resultado % 2 == 0 or resultado > 7 :
            count+= 1
    
    return count/simulaciones

print('La probabilidad es :', np.round(tirardados()*100, 2), '%')
# Out:
# La probabilidad es : 65.8 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
import numpy as np

# Diccionario
d = {}

for i in range(60):
    if i < 10:
        d[i] = 'Blanco'
    elif i > 9 and i < 30:
        d[i] = 'Rojo'
    else:
        d[i] = 'Verde'
        
for i in range(1000): #cantidad de simulaciones
    list = []
    for i in range(5): #simulaciones
        list.append(d[random.randint(0,59)])  #cantidad de 
        
    list = np.array(list)
    Blanco = sum(list == 'Blanco')
    Rojo = sum(list == 'Rojo')
    Verde = sum(list == 'Verde')

    if Blanco == 3 and Rojo == 2:
        parte_a += 1
    
    if Rojo == 5 or Blanco == 5 or Verde ==5:
        parte_b +=1

print('La probabilidad 3 blanco y 2 rojo es:', round(parte_a/simulaciones*100,2),'%')
print('La probabilidad es de todos los colores:', round(parte_b/simulaciones*100,2),'%')
# Out:
# La probabilidad 3 blanco y 2 rojo es: 2.5 %
# La probabilidad es de todos los colores: 14.2 %
